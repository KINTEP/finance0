# %%
#Fourier analysis and observation
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
t1 = np.array([i for i in range(100)])

# %%
plt.plot(np.sin(t1*10))

# %%
l1 = [2,4,1]
l2 = [0,1,1]
l3 = [9,5,6]
l4 = [5,3,1]

df = pd.DataFrame()
df["one"] = l1
df["two"] = l2
df["three"] = l3
df["four"] = l4

# %%
np.array(df)
# Out:
# array([[2, 0, 9, 5],
#        [4, 1, 5, 3],
#        [1, 1, 6, 1]], dtype=int64)

# %%
l1[::-1]
# Out:
# [1, 4, 2]

# %%
def fourier(sequence):
    N = len(sequence)
    X = np.array([i for i in range(1, N+1)])
    sum1 = np.zeros(N)
    amp = []
    for i in range(400):
        d1 = np.dot(sequence, np.sin(i*X))
        amp.append(d1)
        sum1 += d1*np.sin(i*X)
    return sum1, amp

def forcast(x, amplitudes):
    sum1 = np.zeros(len(x))
    for i in range(len(amplitudes)):
        sum1 += amplitudes[i]*np.sin(i*x)
    return sum1

def normalize(sequence):
    max1 = np.max(sequence)
    min1 = np.min(sequence)
    data = []
    for val in sequence:
        norm = (val - min1)/(max1 - min1)
        data.append(norm)
    return data

# %%
l1 = [2,3,4]

np.diag(l1)
# Out:
# array([[2, 0, 0],
#        [0, 3, 0],
#        [0, 0, 4]])

# %%
np.sqrt(10)
# Out:
# 3.1622776601683795

# %%
def square_mat(seq):
    N = len(seq)
    root = int(np.sqrt(N))
    mat = []
    start = 0
    end = root
    for i in range(root):
        mat.append(seq[start:end])
        start += root
        end += root
    return mat

# %%
seq1 = [1,2,3,4,5,2,0,1,2,4,5,7,10,12,15,9,4,3,2,1,0,3,4,5,6,9]

# %%
plt.plot(seq1)

# %%
square_mat([1,2,4,5,4,5,1,3,1,1,2,3,4,1,3,9])
# Out:
# [[1, 2, 4, 5], [4, 5, 1, 3], [1, 1, 2, 3], [4, 1, 3, 9]]

# %%
l2 = l1[::-1]
l2
# Out:
# [4, 3, 2]

# %%
df = pd.read_csv("S&P5001.csv")

# %%
#data.head()

# %%
seq1 = data.D1[:100]
f1, amp1 = fourier(seq1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-19755ee391e9> in <module>
# ----> 1 seq1 = data.D1[:100]
#       2 f1, amp1 = fourier(seq1)
#
# NameError: name 'data' is not defined

# %%
np.corrcoef(seq1, f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c32c0c3f8216> in <module>
# ----> 1 np.corrcoef(seq1, f1)
#
# NameError: name 'f1' is not defined

# %%
plt.plot(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7115eb8d8e1f> in <module>
# ----> 1 plt.plot(f1)
#
# NameError: name 'f1' is not defined

# %%
plt.bar([x for x in range(1, len(amp1)+1)][:50],np.abs(amp1)[:50])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4d1e2586a4bc> in <module>
# ----> 1 plt.bar([x for x in range(1, len(amp1)+1)][:50],np.abs(amp1)[:50])
#
# NameError: name 'amp1' is not defined

# %%
plt.hist(np.abs(amp1), bins = 1000)[0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c162d360d48a> in <module>
# ----> 1 plt.hist(np.abs(amp1), bins = 1000)[0][0]
#
# NameError: name 'amp1' is not defined

# %%
plt.bar([x for x in range(len(amp1[:50]))], np.abs(amp1[:50]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f3c9dc9c8440> in <module>
# ----> 1 plt.bar([x for x in range(len(amp1[:50]))], np.abs(amp1[:50]))
#
# NameError: name 'amp1' is not defined

# %%
amp1.index(max(amp1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f4e51b324eb8> in <module>
# ----> 1 amp1.index(max(amp1))
#
# NameError: name 'amp1' is not defined

# %%
len(amp1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d1a8748523f1> in <module>
# ----> 1 len(amp1)
#
# NameError: name 'amp1' is not defined

# %%
X = np.array([i for i in range(100)])
plt.plot(np.sin(X))

# %%
fork1 = forcast(x=X, amplitudes=amp1)
plt.plot(fork1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-507bf8d602a0> in <module>
# ----> 1 fork1 = forcast(x=X, amplitudes=amp1)
#       2 plt.plot(fork1)
#
# NameError: name 'amp1' is not defined

# %%
np.corrcoef(fork1, seq1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e63146f0e01c> in <module>
# ----> 1 np.corrcoef(fork1, seq1)
#
# NameError: name 'fork1' is not defined

# %%
fork2 = forcast(x=np.array([x for x in range(100, 150)]), amplitudes=amp1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2e535f6d7c70> in <module>
# ----> 1 fork2 = forcast(x=np.array([x for x in range(100, 150)]), amplitudes=amp1)
#
# NameError: name 'amp1' is not defined

# %%
plt.plot(fork2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8f530d695919> in <module>
# ----> 1 plt.plot(fork2)
#
# NameError: name 'fork2' is not defined

# %%
plt.plot(normalize(data.D1[100:150]))
plt.plot(normalize(fork2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-fb94eab5b6bf> in <module>
# ----> 1 plt.plot(normalize(data.D1[100:150]))
#       2 plt.plot(normalize(fork2))
#
# NameError: name 'data' is not defined

# %%
np.corrcoef(fork2, data.D1[100:150])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3a03e6d8c251> in <module>
# ----> 1 np.corrcoef(fork2, data.D1[100:150])
#
# NameError: name 'fork2' is not defined

# %%
def harmonic_series(fundamental_freq, n):
    seq = [fundamental_freq]
    for i in range(2, n):
        seq.append(seq[-1]*i)
    return seq

def harmonic_series2(fundamental_freq, n):
    seq = [fundamental_freq]
    for i in range(2, n):
        seq.append(seq[-1]/i)
    return seq

# %%
harmonic_series(10, 5)
# Out:
# [10, 20, 60, 240]

# %%
N = len(seq1)
X1 = np.array([i for i in range(1, N+1)])
hams = harmonic_series(5, 20)
sam = np.zeros(N)
for v in hams:
    d1 = np.dot(seq1, np.sin(v*X1))
    sam += d1*np.sin(v*X1)

# %%
np.corrcoef(seq1, sam)
# Out:
# array([[1.        , 0.70449013],
#        [0.70449013, 1.        ]])

# %%
N = len(seq1)
X1 = np.array([i for i in range(1, N+1)])
hams2 = harmonic_series2(5,20)
sam1 = np.zeros(N)
for v in hams2:
    d1 = np.dot(seq1, np.sin(v*X1))
    sam1 += d1*np.sin(v*X1)

# %%
np.corrcoef(seq1, sam1+sam)
# Out:
# array([[1.       , 0.8248641],
#        [0.8248641, 1.       ]])

# %%
plt.plot(normalize(sam1+sam))
plt.plot(normalize(data.D1[:N]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-72c5da89c25e> in <module>
#       1 plt.plot(normalize(sam1+sam))
# ----> 2 plt.plot(normalize(data.D1[:N]))
#
# NameError: name 'data' is not defined

# %%
seq10 = [1,2,3,1,3,4,5,6,8,10,2,1,3,4,5,4,3,10,9,8,7,6,5,4,4,3,2,3,4,5,6,7,10,13,15]

# %%
plt.plot(seq10)

# %%
print(seq10)
# Out:
# [1, 2, 3, 1, 3, 4, 5, 6, 8, 10, 2, 1, 3, 4, 5, 4, 3, 10, 9, 8, 7, 6, 5, 4, 4, 3, 2, 3, 4, 5, 6, 7, 10, 13, 15]

# %%
seq1 = [1,2,3,4,5,1]
print(seq1)
# Out:
# [1, 2, 3, 4, 5, 1]

# %%
#seq10 = list(df.CLOSE[:100])
window = 5

start = 0
end = window

data = {}
N = len(seq10) - window
for i in range(N):
    l1 = seq10[start:end+1]
    l2 = seq10[end:end+window+1]
    if len(l2) < len(l1):
        break
    if max(l1) == l1[-1] and max(l2) == l2[0]:
        data[end] = l1[-1]
    if min(l1) == l1[-1] and min(l2) == l2[0]:
        data[end] = l1[-1]
    start += 1
    end += 1
    #print(l1, l2)
print(data)
# Out:
# {9: 10, 11: 1, 17: 10, 26: 2}

# %%
def turning_points(seq, wind = 5):
    start = 0
    end = wind

    data = {}
    N = len(seq) - wind
    for i in range(N):
        l1 = seq[start:end+1]
        l2 = seq[end:end+wind+1]
        if len(l2) < len(l1):
            break
        if max(l1) == l1[-1] and max(l2) == l2[0]:
            data[end] = l1[-1]
        if min(l1) == l1[-1] and min(l2) == l2[0]:
            data[end] = l1[-1]
        start += 1
        end += 1
    #This portion was put into a dataframe so i could drop the duplicate values easily
    df2 = pd.DataFrame()
    df2["values"] = data.values()
    df2["keys"] = data.keys()
    df2.drop_duplicates(subset = "values", keep = "first", inplace = True)
    return df2["keys"], df2["values"]

def make_norm(df_keys, seq):
    latta = list(df_keys)
    nana1 = len(latta)
    norm = normalize(seq[:latta[0]])
    for i in range(nana1-1):
        l1 = normalize(seq[latta[i]:latta[i+1]])
        norm += l1
    norm += normalize(seq[latta[-1]:])
    return norm

def get_tp(seq, wind):
    TP, _ = turning_points(wind = wind, seq = seq)
    norm = make_norm(df_keys = TP, seq = seq)
    return norm

# %%
seq11 = list(df.CLOSE[100:220])

# %%
gt1 = get_tp(seq11, 20)

# %%
plt.plot(gt1)

# %%
plt.plot(seq11)
plt.scatter(turning_points(wind = 20, seq = seq11)[0], turning_points(wind = 20, seq = seq11)[1])

# %%
plt.plot(seq10)
plt.scatter(df2["keys"], df2["values"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-74ed699ff484> in <module>
#       1 plt.plot(seq10)
# ----> 2 plt.scatter(df2["keys"], df2["values"])
#
# NameError: name 'df2' is not defined

# %%
df2 = pd.DataFrame()
df2["values"] = data.values()
df2["keys"] = data.keys()

# %%
df2.drop_duplicates(subset = "values", keep = "first", inplace = True)

# %%
df2
# Out:
#    values  keys
# 0      10     9
# 1       1    11
# 3       2    26

# %%
def normalize(sequence):
    max1 = np.max(sequence)
    min1 = np.min(sequence)
    data = []
    for val in sequence:
        norm = (val - min1)/(max1 - min1)
        data.append(norm)
    return data

# %%
start = 0
end = 2
latta = list(df2["keys"])
nana1 = len(latta)
norm = normalize(seq10[:latta[0]])
for i in range(nana1-1):
    l1 = normalize(seq10[latta[i]:latta[i+1]])
    norm += l1
norm += normalize(seq10[latta[-1]:])

# %%
plt.plot(norm)

# %%
plt.plot(seq10)

# %%
len(norm)
# Out:
# 35

# %%
print(latta)
# Out:
# [9, 11, 26]

# %%
print(seq10)
# Out:
# [1, 2, 3, 1, 3, 4, 5, 6, 8, 10, 2, 1, 3, 4, 5, 4, 3, 10, 9, 8, 7, 6, 5, 4, 4, 3, 2, 3, 4, 5, 6, 7, 10, 13, 15]

# %%
nani = normalize(seq10[:9+1]) + normalize(seq10[9+1:11+1]) + normalize(seq10[11+1:]) #+ normalize(seq10[26:])
print(seq10[:9+1]) i+1
print(seq10[9+1:11+1])
print(seq10[11+1:])
#print(seq10[26:])
#print(nani)
# Out:
#   File "<ipython-input-60-7785834dab07>", line 2
#     print(seq10[:9+1]) i+1
#                        ^
# SyntaxError: invalid syntax

# %%
print(seq10)
# Out:
# [1, 2, 3, 1, 3, 4, 5, 6, 8, 10, 2, 1, 3, 4, 5, 4, 3, 10, 9, 8, 7, 6, 5, 4, 4, 3, 2, 3, 4, 5, 6, 7, 10, 13, 15]

# %%
print(seq10[:latta[0]])
for v in range(len(latta)-1):
    l1 = seq10[latta[v]:latta[v+1]]
    print(l1)
print(seq10[latta[-1]:])
# Out:
# [1, 2, 3, 1, 3, 4, 5, 6, 8]
# [10, 2]
# [1, 3, 4, 5, 4, 3, 10, 9, 8, 7, 6, 5, 4, 4, 3]
# [2, 3, 4, 5, 6, 7, 10, 13, 15]

# %%
plt.plot(nani)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-dcda115da42a> in <module>
# ----> 1 plt.plot(nani)
#
# NameError: name 'nani' is not defined

# %%
plt.plot(seq10)

# %%
len(nani)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-7c50974f4a6b> in <module>
# ----> 1 len(nani)
#
# NameError: name 'nani' is not defined

# %%
f = [4,1,8,3]

# %%
plt.plot(f)

# %%
ff1 = np.fft.fft(f)
inv = np.fft.ifft(ff1)

# %%
np.corrcoef(inv, f)
# Out:
# array([[1.+0.j, 1.+0.j],
#        [1.+0.j, 1.+0.j]])

# %%
freq = np.fft.fftfreq(len(f))

# %%
ff1
# Out:
# array([16.+0.j, -4.+2.j,  8.+0.j, -4.-2.j])

# %%
time = np.linspace(1,10,len(f))
real = ff1.real
imag = ff1.imag
print(real)
print(imag)
# Out:
# [16. -4.  8. -4.]
# [ 0.  2.  0. -2.]

# %%
NN = len(f)
n = np.arange(NN)
k = n.reshape((NN,1))
print(n*k)
# Out:
# [[0 0 0 0]
#  [0 1 2 3]
#  [0 2 4 6]
#  [0 3 6 9]]

# %%
total = np.zeros(len(f))

for i in range(len(real)):
    total += real[i]*np.sin(freq[i]*n*2*np.pi/len(f))
    total += imag[i]*np.cos(freq[i]*n*2*np.pi/len(f))

# %%
def dft(x):
    x = np.asarray(x, dtype=float)
    N = x.shape[0]
    n = np.arange(N)
    k = n.reshape((N, 1))
    M = np.exp(-2j * np.pi * k * n / N)
    return np.dot(M, x)

# %%
x = np.asarray(f, dtype=float)
print(x)
N = x.shape[0]
print(N)
n = np.arange(N)
k = n.reshape((N, 1))
print(n)
print(k)
# Out:
# [4. 1. 8. 3.]
# 4
# [0 1 2 3]
# [[0]
#  [1]
#  [2]
#  [3]]

# %%
M = np.exp(-2j * np.pi * k * n / N)
print(M)
# Out:
# [[ 1.0000000e+00+0.0000000e+00j  1.0000000e+00+0.0000000e+00j
#    1.0000000e+00+0.0000000e+00j  1.0000000e+00+0.0000000e+00j]
#  [ 1.0000000e+00+0.0000000e+00j  6.1232340e-17-1.0000000e+00j
#   -1.0000000e+00-1.2246468e-16j -1.8369702e-16+1.0000000e+00j]
#  [ 1.0000000e+00+0.0000000e+00j -1.0000000e+00-1.2246468e-16j
#    1.0000000e+00+2.4492936e-16j -1.0000000e+00-3.6739404e-16j]
#  [ 1.0000000e+00+0.0000000e+00j -1.8369702e-16+1.0000000e+00j
#   -1.0000000e+00-3.6739404e-16j  5.5109106e-16-1.0000000e+00j]]

# %%
np.dot(M, x)
# Out:
# array([16.+0.00000000e+00j, -4.+2.00000000e+00j,  8.+7.34788079e-16j,
#        -4.-2.00000000e+00j])

# %%
x
# Out:
# array([4., 1., 8., 3.])

# %%
k*n * 2j
# Out:
# array([[0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j],
#        [0. +0.j, 0. +2.j, 0. +4.j, 0. +6.j],
#        [0. +0.j, 0. +4.j, 0. +8.j, 0.+12.j],
#        [0. +0.j, 0. +6.j, 0.+12.j, 0.+18.j]])

# %%
arr1 = np.array(k*n*-2j)
np.exp(arr1)
# Out:
# array([[ 1.        -0.j        ,  1.        -0.j        ,
#          1.        -0.j        ,  1.        -0.j        ],
#        [ 1.        -0.j        , -0.41614684-0.90929743j,
#         -0.65364362+0.7568025j ,  0.96017029+0.2794155j ],
#        [ 1.        -0.j        , -0.65364362+0.7568025j ,
#         -0.14550003-0.98935825j,  0.84385396+0.53657292j],
#        [ 1.        -0.j        ,  0.96017029+0.2794155j ,
#          0.84385396+0.53657292j,  0.66031671+0.75098725j]])

# %%
k*n/2
# Out:
# array([[0. , 0. , 0. , 0. ],
#        [0. , 0.5, 1. , 1.5],
#        [0. , 1. , 2. , 3. ],
#        [0. , 1.5, 3. , 4.5]])

# %%
dft(f)
# Out:
# array([16.+0.00000000e+00j, -4.+2.00000000e+00j,  8.+7.34788079e-16j,
#        -4.-2.00000000e+00j])

# %%
np.asarray(f, dtype=float)
# Out:
# array([4., 1., 8., 3.])

# %%
f
# Out:
# [4, 1, 8, 3]

# %%
plt.scatter(time, total, color = "red")
plt.plot(time, total)

# %%
total
# Out:
# array([ 0.        , -5.65685425, -8.        , -5.65685425])

# %%
np.corrcoef(total, f)
# Out:
# array([[ 1.        , -0.31183541],
#        [-0.31183541,  1.        ]])

# %%
freq
# Out:
# array([ 0.  ,  0.25, -0.5 , -0.25])

# %%
def weierstrass(a,b,n,x):
    a1 = a**n
    b1 = b**n
    ans = b1*np.cos(a1*x*np.pi)
    return ans

# %%
xx = np.arange(100)
x2 = np.linspace(-2,2,100)
w1 = weierstrass(a=0.1,b=3.4,n=3,x=x2)

# %%
plt.plot(w1)

# %%
def generate_data(cov_matrx, n, intial_values):
    inv = np.linalg.inv(cov_matrx)
    data = [intial_values]
    for i in range(n):
        vals = np.dot(data[-1], data[-1].transpose())
        dot = -0.5 * vals*inv
        exp = np.exp(dot)
        data.append(exp)
    return data

# %%
mat = np.array([[1,0.9],[0.9,1]])
vec = np.array([[0.3,-2.9]])

# %%
mat * np.dot(vec, vec.transpose())
# Out:
# array([[8.5 , 7.65],
#        [7.65, 8.5 ]])

# %%
gen1 = generate_data(cov_matrx = mat, n = 10, intial_values = vec)
print(gen1)
# Out:
# [array([[ 0.3, -2.9]]), array([[1.92982607e-10, 5.53392984e+08],
#        [5.53392984e+08, 1.92982607e-10]]), array([[0.       , 1.6584312],
#        [1.6584312, 0.       ]]), array([[7.18834726e-04, 1.00000000e+00],
#        [1.00000000e+00, 7.18834726e-04]]), array([[0.07196465, 1.00341081],
#        [1.00341081, 0.07196465]]), array([[0.06972545, 1.40782767],
#        [1.40782767, 0.06972545]]), array([[0.00536141, 1.5919746 ],
#        [1.5919746 , 0.00536141]]), array([[0.00126903, 1.04125849],
#        [1.04125849, 0.00126903]]), array([[0.05765878, 1.00627882],
#        [1.00627882, 0.05765878]]), array([[0.06901179, 1.316314  ],
#        [1.316314  , 0.06901179]]), array([[0.01033495, 1.53771932],
#        [1.53771932, 0.01033495]])]

# %%
x_vals = []
y_vals = []

for v in gen1:
    x_vals.append(v[0][0])
    y_vals.append(v[0][1])

# %%
plt.scatter(x_vals, y_vals)

# %%
np.corrcoef(x_vals, y_vals)
# Out:
# array([[ 1.        , -0.20131148],
#        [-0.20131148,  1.        ]])

# %%
#import numpy as np
#import matplotlib.pyplot as plt
from scipy import stats


n = 50
x = np.linspace(0, 10, n)

# Define the gaussian with mu = sin(x) and negligible covariance matrix
norm = stats.multivariate_normal(mean=np.sin(x), cov=np.eye(n) * 1e-6)
#plt.figure(figsize=(16, 6))

# Taking a sample from the distribution and plotting it.
#plt.plot(x, norm.rvs())

# %%
#np.info(np.eye)

# %%
np.eye(5)*2
# Out:
# array([[2., 0., 0., 0., 0.],
#        [0., 2., 0., 0., 0.],
#        [0., 0., 2., 0., 0.],
#        [0., 0., 0., 2., 0.],
#        [0., 0., 0., 0., 2.]])

# %%
np.eye(5) * 1e-6
# Out:
# array([[1.e-06, 0.e+00, 0.e+00, 0.e+00, 0.e+00],
#        [0.e+00, 1.e-06, 0.e+00, 0.e+00, 0.e+00],
#        [0.e+00, 0.e+00, 1.e-06, 0.e+00, 0.e+00],
#        [0.e+00, 0.e+00, 0.e+00, 1.e-06, 0.e+00],
#        [0.e+00, 0.e+00, 0.e+00, 0.e+00, 1.e-06]])

# %%
norm = stats.multivariate_normal(mean=np.zeros(n), cov=np.eye(n))
plt.figure(figsize=(16, 6))

# Taking 3 sample from the distribution and plotting it.
[plt.plot(x, norm.rvs()) for _ in range(5)]
# Out:
# [[<matplotlib.lines.Line2D at 0xa6deeb0>],
# ...

# %%
def kernel(m1, m2, l=1):
    return np.exp(- 1 / (2 * l**2) * (m1[:, None] - m2)**2)

n = 50
x = np.linspace(0, 10, n)
cov = kernel(x, x, 0.44)

norm = stats.multivariate_normal(mean=np.zeros(n), cov=cov)
plt.figure(figsize=(16, 6))
[plt.plot(x, norm.rvs()) for _ in range(5)][0][0]

# %%
x[:, None] - x
# Out:
# array([[  0.        ,  -0.20408163,  -0.40816327, ...,  -9.59183673,
#          -9.79591837, -10.        ],
#        [  0.20408163,   0.        ,  -0.20408163, ...,  -9.3877551 ,
#          -9.59183673,  -9.79591837],
#        [  0.40816327,   0.20408163,   0.        , ...,  -9.18367347,
#          -9.3877551 ,  -9.59183673],
#        ...,
#        [  9.59183673,   9.3877551 ,   9.18367347, ...,   0.        ,
#          -0.20408163,  -0.40816327],
#        [  9.79591837,   9.59183673,   9.3877551 , ...,   0.20408163,
#           0.        ,  -0.20408163],
#        [ 10.        ,   9.79591837,   9.59183673, ...,   0.40816327,
#           0.20408163,   0.        ]])

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
np.exp(1)
# Out:
# 2.718281828459045
